# %% [markdown]
# # Run AML code in your custom Conda Environment from base image
#
# Create and register my Environment with custom Conda and python packages from my docker image

# %% [markdown]
# ## Check if environment already exists

# %%
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core import Workspace
from azureml.core import Experiment, ScriptRunConfig, Environment

# Name of your Environment
myEnvironmentName = 'myEnvironmentWithACustomDockerImage'

# Get the Workspace
ws = Workspace.from_config()
print(ws.name, "loaded")

try:
    env_name = Environment.get(workspace=ws, name = myEnvironmentName)
    print('Environment {} already exists, stop program'.format(env_name))
except Exception as e:
    print('Environment {} not found. Proceed to create it...'.format(myEnvironmentName))
# Out:
# tbexamaml loaded
# Environment myEnvironmentWithACustomDockerImage not found. Proceed to create it...

# %% [markdown]
# # Create your custom environment using your docker image from your private registry

# %%
# Create the environment
env_name = Environment(name=myEnvironmentName)
# Enable Docker and reference an image
env_name.docker.enabled = True
# To use your own installed packages and disable Conda, set the parameter
env_name.python.user_managed_dependencies=True
env_name.docker.base_image = "<your azure container registry name>.azurecr.io/demo-aml/<name of the docker image>:latest"
env_name.docker.base_image_registry.username = "<azure container registry service principal id>"
env_name.docker.base_image_registry.password = "<service principal password>"

# %% [markdown]
# # Create or attach a compute target

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# Name of the compute target
cluster_name = "CustomAMLCompute"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS3_V2',
                                                           max_nodes=4)
    # Create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True)

# Use get_status() to get a detailed status for the current AmlCompute.
print(compute_target.get_status().serialize())
# Out:
# Found existing compute target.
# {'errors': [], 'creationTime': '2021-03-03T15:54:32.753905+00:00', 'createdBy': {'userObjectId': 'e41d4ef3-c9c5-4f08-a494-4c3cb9d953aa', 'userTenantId': '72f988bf-86f1-41af-91ab-2d7cd011db47', 'userName': 'Tirthankar Barari (TR)'}, 'modifiedTime': '2021-03-03T15:57:24.228416+00:00', 'state': 'Running', 'vmSize': 'STANDARD_DS3_V2'}

# %% [markdown]
# # Now Train the model from your python script

# %%
from azureml.widgets import RunDetails

training_folder = 'diabetes-training'
experiment_name = 'train-diabetes-in-custom-environment'

# Create a script config
script_config = ScriptRunConfig(source_directory=training_folder,
                                script='diabetes_training.py',
                                compute_target=compute_target,
                                environment=env_name) 

# submit the experiment run
experiment = Experiment(workspace=ws, name=experiment_name)
run = experiment.submit(config=script_config)

# Show the running experiment run in the notebook widget
RunDetails(run).show()

# Block until the experiment run has completed
run.wait_for_completion(show_output=True)

# Get logged metrics
metrics = run.get_metrics()
for key in metrics.keys():
        print(key, metrics.get(key))
print('\n')
for file in run.get_file_names():
    print(file)
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
# RunId: train-diabetes-in-custom-environment_1615777097_9dbaf538
# Web View: https://ml.azure.com/experiments/train-diabetes-in-custom-environment/runs/train-diabetes-in-custom-environment_1615777097_9dbaf538?wsid=/subscriptions/7ee5c9fb-ba32-4243-af24-bda7af98f453/resourcegroups/tbexamaml/workspaces/tbexamaml
#
# Streaming azureml-logs/55_azureml-execution-tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d.txt
# ========================================================================================================================
#
# 2021-03-15T02:58:42Z Starting output-watcher...
# 2021-03-15T02:58:42Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-15T02:58:55Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-03-15T02:58:55Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# latest: Pulling from demo-aml/tr-custom-conda-1.0
# 852e50cd189d: Already exists
# a6236801494d: Already exists
# 679c171d6942: Already exists
# bc0a453f6fa1: Pulling fs layer
# e02f26c94520: Pulling fs layer
# 06f5031f218c: Pulling fs layer
# ba6605dfb284: Pulling fs layer
# ddeef4fd9f62: Pulling fs layer
# 0ad0866b5c48: Pulling fs layer
# 0ad0866b5c48: Waiting
# ddeef4fd9f62: Waiting
# ba6605dfb284: Waiting
# bc0a453f6fa1: Download complete
# 06f5031f218c: Verifying Checksum
# 06f5031f218c: Download complete
# bc0a453f6fa1: Pull complete
# 0ad0866b5c48: Download complete
# e02f26c94520: Pull complete
# 06f5031f218c: Pull complete
# ddeef4fd9f62: Verifying Checksum
# ddeef4fd9f62: Download complete
# ba6605dfb284: Verifying Checksum
# ba6605dfb284: Download complete
# ba6605dfb284: Pull complete
# ddeef4fd9f62: Pull complete
# 0ad0866b5c48: Pull complete
# Digest: sha256:89690468bce52db07de777d21a600b2c87166c1f57685aa24bfb9e14949fcafd
# Status: Downloaded newer image for tbdemoacr.azurecr.io/demo-aml/tr-custom-conda-1.0:latest
# tbdemoacr.azurecr.io/demo-aml/tr-custom-conda-1.0:latest
# 2021-03-15T02:59:28Z Check if container train-diabetes-in-custom-environment_1615777097_9dbaf538 already exist exited with 0,
#
# f36ed5ebefdc08c3036d516bcb25965c059128f4a950d1d58a170b6fe7ad3e90
# 2021/03/15 02:59:34 Starting App Insight Logger for task:  containerSetup
# 2021/03/15 02:59:34 Version: 3.0.01524.0007 Branch: .SourceBranch Commit: d7729eb
# 2021/03/15 02:59:34 Entered ContainerSetupTask - Preparing infiniband
# 2021/03/15 02:59:34 Starting infiniband setup
# 2021/03/15 02:59:34 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/15 02:59:34 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/15 02:59:34 Starting setupPasswordLessSSH setup
# 2021/03/15 02:59:34 Setting up Passwordless SSH in Container
# 2021/03/15 02:59:34 Setting up Passwordless SSH in Container
# 2021-03-15T02:59:34Z Setting up Passwordless SSH in Container
# dpkg: warning: downgrading libkrb5support0:amd64 from 1.17-3+deb10u1 to 1.13.2+dfsg-5ubuntu2.1
# (Reading database ... 12571 files and directories currently installed.)
# Preparing to unpack libkrb5support0_1.13.2+dfsg-5ubuntu2.1_amd64.deb ...
# Unpacking libkrb5support0:amd64 (1.13.2+dfsg-5ubuntu2.1) over (1.17-3+deb10u1) ...
# Setting up libkrb5support0:amd64 (1.13.2+dfsg-5ubuntu2.1) ...
# Processing triggers for libc-bin (2.28-10) ...
# dpkg: warning: downgrading libk5crypto3:amd64 from 1.17-3+deb10u1 to 1.13.2+dfsg-5ubuntu2.1
# (Reading database ... 12571 files and directories currently installed.)
# Preparing to unpack libk5crypto3_1.13.2+dfsg-5ubuntu2.1_amd64.deb ...
# Unpacking libk5crypto3:amd64 (1.13.2+dfsg-5ubuntu2.1) over (1.17-3+deb10u1) ...
# Setting up libk5crypto3:amd64 (1.13.2+dfsg-5ubuntu2.1) ...
# Processing triggers for libc-bin (2.28-10) ...
# dpkg: warning: downgrading libkeyutils1:amd64 from 1.6-6 to 1.5.9-8ubuntu1
# (Reading database ... 12571 files and directories currently installed.)
# Preparing to unpack libkeyutils1_1.5.9-8ubuntu1_amd64.deb ...
# Unpacking libkeyutils1:amd64 (1.5.9-8ubuntu1) over (1.6-6) ...
# Setting up libkeyutils1:amd64 (1.5.9-8ubuntu1) ...
# Processing triggers for libc-bin (2.28-10) ...
# dpkg: warning: downgrading libkrb5-3:amd64 from 1.17-3+deb10u1 to 1.13.2+dfsg-5ubuntu2.1
# (Reading database ... 12571 files and directories currently installed.)
# Preparing to unpack libkrb5-3_1.13.2+dfsg-5ubuntu2.1_amd64.deb ...
# Unpacking libkrb5-3:amd64 (1.13.2+dfsg-5ubuntu2.1) over (1.17-3+deb10u1) ...
# Setting up libkrb5-3:amd64 (1.13.2+dfsg-5ubuntu2.1) ...
# Processing triggers for libc-bin (2.28-10) ...
# dpkg: warning: downgrading libgssapi-krb5-2:amd64 from 1.17-3+deb10u1 to 1.13.2+dfsg-5ubuntu2.1
# (Reading database ... 12569 files and directories currently installed.)
# Preparing to unpack libgssapi-krb5-2_1.13.2+dfsg-5ubuntu2.1_amd64.deb ...
# Unpacking libgssapi-krb5-2:amd64 (1.13.2+dfsg-5ubuntu2.1) over (1.17-3+deb10u1) ...
# Setting up libgssapi-krb5-2:amd64 (1.13.2+dfsg-5ubuntu2.1) ...
# Processing triggers for libc-bin (2.28-10) ...
# Selecting previously unselected package libssl1.0.0:amd64.
# (Reading database ... 12569 files and directories currently installed.)
# Preparing to unpack libssl1.0.0_1.0.2g-1ubuntu4.15_amd64.deb ...
# Unpacking libssl1.0.0:amd64 (1.0.2g-1ubuntu4.15) ...
# Setting up libssl1.0.0:amd64 (1.0.2g-1ubuntu4.15) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# Processing triggers for libc-bin (2.28-10) ...
# Selecting previously unselected package multiarch-support.
# (Reading database ... 12588 files and directories currently installed.)
# Preparing to unpack multiarch-support_2.23-0ubuntu10_amd64.deb ...
# Unpacking multiarch-support (2.23-0ubuntu10) ...
# Setting up multiarch-support (2.23-0ubuntu10) ...
# Selecting previously unselected package libwrap0:amd64.
# (Reading database ... 12591 files and directories currently installed.)
# Preparing to unpack libwrap0_7.6.q-25_amd64.deb ...
# Unpacking libwrap0:amd64 (7.6.q-25) ...
# Setting up libwrap0:amd64 (7.6.q-25) ...
# dpkg: warning: downgrading libbsd0:amd64 from 0.9.1-2 to 0.8.2-1
# (Reading database ... 12602 files and directories currently installed.)
# Preparing to unpack libbsd0_0.8.2-1_amd64.deb ...
# Unpacking libbsd0:amd64 (0.8.2-1) over (0.9.1-2) ...
# Setting up libbsd0:amd64 (0.8.2-1) ...
# Processing triggers for libc-bin (2.28-10) ...
# dpkg: warning: downgrading libedit2:amd64 from 3.1-20181209-1 to 3.1-20150325-1ubuntu2
# (Reading database ... 12601 files and directories currently installed.)
# Preparing to unpack libedit2_3.1-20150325-1ubuntu2_amd64.deb ...
# Unpacking libedit2:amd64 (3.1-20150325-1ubuntu2) over (3.1-20181209-1) ...
# dpkg: dependency problems prevent configuration of libedit2:amd64:
#  libedit2:amd64 depends on libtinfo5 (>= 6); however:
#   Package libtinfo5 is not installed.
#
# dpkg: error processing package libedit2:amd64 (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for libc-bin (2.28-10) ...
# Errors were encountered while processing:
#  libedit2:amd64
# 2021/03/15 02:59:37 Unable to install local SSH-server package.
# 2021-03-15T02:59:37Z Unable to install local SSH-server package.
# 2021/03/15 02:59:37 Error in setupPasswordLessSSH
# 2021/03/15 02:59:37 exit status 1
# 2021/03/15 02:59:37 All App Insights Logs was send successfully
# 2021/03/15 02:59:37 exit status 1
# 2021-03-15T02:59:37Z Restart and configure docker container with fallback
# 2021-03-15T02:59:37Z Removed all existing containers
# 2021-03-15T02:59:37Z Check if container train-diabetes-in-custom-environment_1615777097_9dbaf538 already exist exited with 0,
#
# 5d61d565c3c7be9689818608d8110b831d4524b83f829c9f945dacec7746b94d
# 2021/03/15 02:59:38 Starting App Insight Logger for task:  containerSetup
# 2021/03/15 02:59:38 Version: 3.0.01524.0007 Branch: .SourceBranch Commit: d7729eb
# 2021/03/15 02:59:38 Entered ContainerSetupTask - Preparing infiniband
# 2021/03/15 02:59:38 Starting infiniband setup
# 2021/03/15 02:59:38 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/15 02:59:38 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/15 02:59:38 Starting setupPasswordLessSSH setup
# 2021/03/15 02:59:38 Setting up Passwordless SSH in Container
# 2021/03/15 02:59:38 Setting up Passwordless SSH in Container
# 2021-03-15T02:59:38Z Setting up Passwordless SSH in Container
# 2021/03/15 02:59:38 Executing apt-get update
# 2021/03/15 02:59:40 Command Output: Get:1 http://security.debian.org/debian-security buster/updates InRelease [65.4 kB]
# Get:2 http://deb.debian.org/debian buster InRelease [122 kB]
# Get:3 http://deb.debian.org/debian buster-updates InRelease [51.9 kB]
# Get:4 http://security.debian.org/debian-security buster/updates/main amd64 Packages [268 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 Packages [7907 kB]
# Get:6 http://deb.debian.org/debian buster-updates/main amd64 Packages.diff/Index [5656 B]
# Get:7 http://deb.debian.org/debian buster-updates/main amd64 Packages 2020-12-24-1401.30.pdiff [286 B]
# Get:8 http://deb.debian.org/debian buster-updates/main amd64 Packages 2021-01-29-2000.47.pdiff [408 B]
# Get:9 http://deb.debian.org/debian buster-updates/main amd64 Packages 2021-02-07-1359.56.pdiff [2302 B]
# Get:9 http://deb.debian.org/debian buster-updates/main amd64 Packages 2021-02-07-1359.56.pdiff [2302 B]
# Fetched 8422 kB in 2s (5138 kB/s)
# Reading package lists...
#
# 2021/03/15 02:59:40 Command Error:
# 2021/03/15 02:59:40 Executing dpkg --configure -a; apt-get install -y --no-install-recommends openssh-client openssh-server iproute2
# 2021/03/15 02:59:45 Command Output: Reading package lists...
# Building dependency tree...
# Reading state information...
# openssh-client is already the newest version (1:7.9p1-10+deb10u2).
# openssh-client set to manually installed.
# The following additional packages will be installed:
#   libcap2 libcap2-bin libelf1 libmnl0 libncurses6 libprocps7 libwrap0
#   libxtables12 openssh-sftp-server procps
# Suggested packages:
#   iproute2-doc molly-guard monkeysphere rssh ssh-askpass ufw
# Recommended packages:
#   libatm1 libpam-cap libgpm2 default-logind | logind | libpam-systemd
#   ncurses-term psmisc
# The following NEW packages will be installed:
#   iproute2 libcap2 libcap2-bin libelf1 libmnl0 libncurses6 libprocps7 libwrap0
#   libxtables12 openssh-server openssh-sftp-server procps
# 0 upgraded, 12 newly installed, 0 to remove and 19 not upgraded.
# Need to get 2004 kB of archives.
# After this operation, 6905 kB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main amd64 libcap2 amd64 1:2.25-2 [17.6 kB]
# Get:2 http://deb.debian.org/debian buster/main amd64 libelf1 amd64 0.176-1.1 [161 kB]
# Get:3 http://deb.debian.org/debian buster/main amd64 libmnl0 amd64 1.0.4-2 [12.2 kB]
# Get:4 http://deb.debian.org/debian buster/main amd64 libxtables12 amd64 1.8.2-4 [80.0 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 libcap2-bin amd64 1:2.25-2 [28.8 kB]
# Get:6 http://deb.debian.org/debian buster/main amd64 iproute2 amd64 4.20.0-2+deb10u1 [826 kB]
# Get:7 http://deb.debian.org/debian buster/main amd64 libncurses6 amd64 6.1+20181013-2+deb10u2 [102 kB]
# Get:8 http://deb.debian.org/debian buster/main amd64 libprocps7 amd64 2:3.3.15-2 [61.7 kB]
# Get:9 http://deb.debian.org/debian buster/main amd64 procps amd64 2:3.3.15-2 [259 kB]
# Get:10 http://deb.debian.org/debian buster/main amd64 libwrap0 amd64 7.6.q-28 [58.7 kB]
# Get:11 http://deb.debian.org/debian buster/main amd64 openssh-sftp-server amd64 1:7.9p1-10+deb10u2 [44.6 kB]
# Get:12 http://deb.debian.org/debian buster/main amd64 openssh-server amd64 1:7.9p1-10+deb10u2 [352 kB]
# Fetched 2004 kB in 0s (46.1 MB/s)
# Selecting previously unselected package libcap2:amd64.
# (Reading database ...
# (Reading database ... 5%
# (Reading database ... 10%
# (Reading database ... 15%
# (Reading database ... 20%
# (Reading database ... 25%
# (Reading database ... 30%
# (Reading database ... 35%
# (Reading database ... 40%
# (Reading database ... 45%
# (Reading database ... 50%
# (Reading database ... 55%
# (Reading database ... 60%
# (Reading database ... 65%
# (Reading database ... 70%
# (Reading database ... 75%
# (Reading database ... 80%
# (Reading database ... 85%
# (Reading database ... 90%
# (Reading database ... 95%
# (Reading database ... 100%
# (Reading database ... 12571 files and directories currently installed.)
# Preparing to unpack .../00-libcap2_1%3a2.25-2_amd64.deb ...
# Unpacking libcap2:amd64 (1:2.25-2) ...
# Selecting previously unselected package libelf1:amd64.
# Preparing to unpack .../01-libelf1_0.176-1.1_amd64.deb ...
# Unpacking libelf1:amd64 (0.176-1.1) ...
# Selecting previously unselected package libmnl0:amd64.
# Preparing to unpack .../02-libmnl0_1.0.4-2_amd64.deb ...
# Unpacking libmnl0:amd64 (1.0.4-2) ...
# Selecting previously unselected package libxtables12:amd64.
# Preparing to unpack .../03-libxtables12_1.8.2-4_amd64.deb ...
# Unpacking libxtables12:amd64 (1.8.2-4) ...
# Selecting previously unselected package libcap2-bin.
# Preparing to unpack .../04-libcap2-bin_1%3a2.25-2_amd64.deb ...
# Unpacking libcap2-bin (1:2.25-2) ...
# Selecting previously unselected package iproute2.
# Preparing to unpack .../05-iproute2_4.20.0-2+deb10u1_amd64.deb ...
# Unpacking iproute2 (4.20.0-2+deb10u1) ...
# Selecting previously unselected package libncurses6:amd64.
# Preparing to unpack .../06-libncurses6_6.1+20181013-2+deb10u2_amd64.deb ...
# Unpacking libncurses6:amd64 (6.1+20181013-2+deb10u2) ...
# Selecting previously unselected package libprocps7:amd64.
# Preparing to unpack .../07-libprocps7_2%3a3.3.15-2_amd64.deb ...
# Unpacking libprocps7:amd64 (2:3.3.15-2) ...
# Selecting previously unselected package procps.
# Preparing to unpack .../08-procps_2%3a3.3.15-2_amd64.deb ...
# Unpacking procps (2:3.3.15-2) ...
# Selecting previously unselected package libwrap0:amd64.
# Preparing to unpack .../09-libwrap0_7.6.q-28_amd64.deb ...
# Unpacking libwrap0:amd64 (7.6.q-28) ...
# Selecting previously unselected package openssh-sftp-server.
# Preparing to unpack .../10-openssh-sftp-server_1%3a7.9p1-10+deb10u2_amd64.deb ...
# Unpacking openssh-sftp-server (1:7.9p1-10+deb10u2) ...
# Selecting previously unselected package openssh-server.
# Preparing to unpack .../11-openssh-server_1%3a7.9p1-10+deb10u2_amd64.deb ...
# Unpacking openssh-server (1:7.9p1-10+deb10u2) ...
# Setting up openssh-sftp-server (1:7.9p1-10+deb10u2) ...
# Setting up libprocps7:amd64 (2:3.3.15-2) ...
# Setting up libcap2:amd64 (1:2.25-2) ...
# Setting up libcap2-bin (1:2.25-2) ...
# Setting up libwrap0:amd64 (7.6.q-28) ...
# Setting up libncurses6:amd64 (6.1+20181013-2+deb10u2) ...
# Setting up libmnl0:amd64 (1.0.4-2) ...
# Setting up libxtables12:amd64 (1.8.2-4) ...
# Setting up procps (2:3.3.15-2) ...
# update-alternatives: using /usr/bin/w.procps to provide /usr/bin/w (w) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/w.1.gz because associated file /usr/share/man/man1/w.procps.1.gz (of link group w) doesn't exist
# Setting up libelf1:amd64 (0.176-1.1) ...
# Setting up openssh-server (1:7.9p1-10+deb10u2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/ssh/sshd_config with new version
# Creating SSH2 RSA key; this may take some time ...
# 2048 SHA256:h7r3iWgE2xDymA8nj9NBIcx24WlitmmuOq0yqVOoIeE root@customamlcompute (RSA)
# Creating SSH2 ECDSA key; this may take some time ...
# 256 SHA256:g25u2y6d2IDbwrmEwYJtOBj2HCCtn2BuLkoAU/EmY8U root@customamlcompute (ECDSA)
# Creating SSH2 ED25519 key; this may take some time ...
# 256 SHA256:NsOdz8+Vv3VlnPZoCl+ZRAgYWd9Xf9M7qb9xfis5kVE root@customamlcompute (ED25519)
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up iproute2 (4.20.0-2+deb10u1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# Processing triggers for libc-bin (2.28-10) ...
#
# 2021/03/15 02:59:45 Command Error: debconf: delaying package configuration, since apt-utils is not installed
#
# ssh-keygen: generating new host keys: DSA
# 2021/03/15 02:59:45 All App Insights Logs was send successfully
# 2021/03/15 02:59:45 App Insight Client has already been closed
# 2021/03/15 02:59:45 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-03-15T02:59:45Z Starting docker container succeeded.
# 2021-03-15T02:59:52Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/03/15 02:58:40 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/03/15 02:58:40 Version: 3.0.01524.0007 Branch: .SourceBranch Commit: d7729eb
# >>>   2021/03/15 02:58:40 runtime.GOOS linux
# >>>   2021/03/15 02:58:40 Reading dyanamic configs
# >>>   2021/03/15 02:58:40 Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=gCpFfTbL8hPl%2BzV43hBdfOZC4SuKqZoJraIo10S4%2FYw%3D
# >>>   2021/03/15 02:58:40 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: not a directory
# >>>   2021/03/15 02:58:40 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed true, isEnable true,
# >>>   2021/03/15 02:58:40 azsecpack isEnable:true,GetDisableVsatlsscan:true
# >>>   2021/03/15 02:58:40 start to install azsecpack..., MachineName is customamlcompute
# >>>
# >>>   2021/03/15 02:58:41
# >>>   2021/03/15 02:58:41
# >>>   2021/03/15 02:58:41 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/03/15 02:58:41 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/03/15 02:58:41 Start to getting gpu count by running nvidia-smi command
# >>>   2021/03/15 02:58:41 GPU count found on the node: 0
# >>>   2021/03/15 02:58:41 AMLComputeXDSEndpoint:  https://eastus-prodk8ds.batchai.core.windows.net
# >>>   2021/03/15 02:58:41 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/03/15 02:58:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/config
# >>>   2021/03/15 02:58:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/wd
# >>>   2021/03/15 02:58:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/shared
# >>>   2021/03/15 02:58:41 Mounting job level file systems
# >>>   2021/03/15 02:58:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts
# >>>   2021/03/15 02:58:41 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/config/.amlcompute.datastorecredentials
# >>>   2021/03/15 02:58:41 Datastore credentials file not found, skipping.
# >>>   2021/03/15 02:58:41 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/config/.master.runtimesastokens
# >>>   2021/03/15 02:58:41 Runtime sas tokens file not found, skipping.
# >>>   2021/03/15 02:58:41 No NFS configured
# >>>   2021/03/15 02:58:41 No Azure File Shares configured
# >>>   2021/03/15 02:58:41 Mounting blob file systems
# >>>   2021/03/15 02:58:41 Blobfuse runtime version 1.3.6
# >>>   2021/03/15 02:58:41 Mounting azureml-blobstore-52262d44-47d0-4548-a4fd-c263e1623241 container from tbexamaml3438399261 account at /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore
# >>>   2021/03/15 02:58:41 Error opening env file:  open /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/03/15 02:58:41 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/03/15 02:58:41 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/03/15 02:58:41 Blobfuse cache size set to 24797 MB.
# >>>   2021/03/15 02:58:41 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24797 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/03/15 02:58:41 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore
# >>>   2021/03/15 02:58:41 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore
# >>>   2021/03/15 02:58:41 Successfully mounted azureml-blobstore-52262d44-47d0-4548-a4fd-c263e1623241 container from tbexamaml3438399261 account at /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore
# >>>   2021/03/15 02:58:41 No unmanaged file systems configured
# >>>   2021/03/15 02:58:41 Start to getting gpu count by running nvidia-smi command
# >>>   2021/03/15 02:58:41 From the policy service, the filtering patterns is: , data store is
# >>>   2021/03/15 02:58:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs
# >>>   2021/03/15 02:58:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/logs
# >>>   2021/03/15 02:58:42 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/outputs
# >>>   2021/03/15 02:58:42 Starting output-watcher...
# >>>   2021/03/15 02:58:42 Single file input dataset is enabled.
# >>>   2021/03/15 02:58:42 Start to pulling docker image: tbdemoacr.azurecr.io/demo-aml/tr-custom-conda-1.0:latest
# >>>   2021/03/15 02:58:42 Start pull docker image: tbdemoacr.azurecr.io
# >>>   2021/03/15 02:58:42 Getting credentials for image tbdemoacr.azurecr.io/demo-aml/tr-custom-conda-1.0:latest with url tbdemoacr.azurecr.io
# >>>   2021/03/15 02:58:42 Container registry is ACR.
# >>>   2021/03/15 02:58:42 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/03/15 02:58:42 Getting ACR Credentials from EMS for environment myEnvironmentWithACustomDockerImage:Autosave_2021-03-15T02:58:17Z_868b5eb9
# >>>   2021/03/15 02:58:42 Requesting XDS for registry details.
# >>>   2021/03/15 02:58:42 Attempt 1 of http call to https://eastus-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/7ee5c9fb-ba32-4243-af24-bda7af98f453/resourceGroups/tbexamaml/workspaces/tbexamaml/clusters/customamlcompute/nodes/tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d?api-version=2018-02-01
# >>>   2021/03/15 02:58:45 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 15
# >>>   FilteredData: 0.
# >>>   2021/03/15 02:58:55 Got container registry details from credentials service for registry address: tbdemoacr.azurecr.io.
# >>>   2021/03/15 02:58:55 Writing ACR Details to file...
# >>>   2021/03/15 02:58:55 Copying ACR Details file to worker nodes...
# >>>   2021/03/15 02:58:55 Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2021/03/15 02:58:55 Begin executing 'Copy ACR Details file' task on Node
# >>>   2021/03/15 02:58:55 'Copy ACR Details file' task Node result: succeeded
# >>>   2021/03/15 02:58:55 Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/03/15 02:58:55 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/03/15 02:58:55 EMS returned tbdemoacr.azurecr.io for environment myEnvironmentWithACustomDockerImage
# >>>   2021/03/15 02:58:55 start login to the docker registry
# >>>   2021/03/15 02:58:55 Successfully logged into the docker registry.
# >>>   2021/03/15 02:58:55 Start run pull docker image command
# >>>   2021/03/15 02:58:55 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/03/15 02:59:27 Pull docker image succeeded.
# >>>   2021/03/15 02:59:27 Pull docker image time: 44.964632719s
# >>>
# >>>   2021/03/15 02:59:28 Docker Version that this nodes use are: 19.03.15+azure
# >>>
# >>>   2021/03/15 02:59:28 Start to getting gpu count by running nvidia-smi command
# >>>   2021/03/15 02:59:28 Setting the memory limit for docker container to be 13675 MB
# >>>   2021/03/15 02:59:28 The env variable file size is 36496 bytes
# >>>   2021/03/15 02:59:28 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/03/15 02:59:28 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,train-diabetes-in-custom-environment_1615777097_9dbaf538,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/certs:/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,13675m,-v,/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs,-v,/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd:/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd,-v,/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538:/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538,-v,/mnt/batch/tasks/shared/LS_root/shared/tracing/train-diabetes-in-custom-environment_1615777097_9dbaf538/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/train-diabetes-in-custom-environment_1615777097_9dbaf538/logs/azureml/tracing,-w,/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/config/.batchai.envlist,--shm-size,2g
# >>>   2021/03/15 02:59:28 the binding /mnt/batch/tasks/shared/LS_root/shared/tracing/train-diabetes-in-custom-environment_1615777097_9dbaf538/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/train-diabetes-in-custom-environment_1615777097_9dbaf538/logs/azureml/tracing is discarded as we already have /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared
# >>>   2021/03/15 02:59:28 the binding /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538:/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538
# >>>   2021/03/15 02:59:28 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,train-diabetes-in-custom-environment_1615777097_9dbaf538,-m,13675m,-w,/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/config/.batchai.envlist,--shm-size,2g,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538:/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538,-v,/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd:/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd,-v,/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/certs:/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/certs
# >>>   2021/03/15 02:59:28 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name train-diabetes-in-custom-environment_1615777097_9dbaf538 -m 13675m -w /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/config/.batchai.envlist --shm-size 2g -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538:/mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538 -v /mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd:/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd -v /mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/certs:/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/certs -d -it --privileged --net=host tbdemoacr.azurecr.io/demo-aml/tr-custom-conda-1.0:latest
# >>>   2021/03/15 02:59:28 Check if container train-diabetes-in-custom-environment_1615777097_9dbaf538 already exist exited with 0,
# >>>
# >>>   2021/03/15 02:59:28 Check if container train-diabetes-in-custom-environment_1615777097_9dbaf538 already exist exited with 0,
# >>>
# >>>   2021/03/15 02:59:30 Attempt 1 of http call to https://eastus.experiments.azureml.net/history/v1.0/private/subscriptions/7ee5c9fb-ba32-4243-af24-bda7af98f453/resourceGroups/tbexamaml/providers/Microsoft.MachineLearningServices/workspaces/tbexamaml/runs/train-diabetes-in-custom-environment_1615777097_9dbaf538/spans
# >>>   2021/03/15 02:59:37 Configure container failed with err:  Docker exec failure when attempting to execute 'containerSetup' task. Error: exit status 1
# >>>   2021/03/15 02:59:37 Restart and configure docker container with fallback
# >>>   2021/03/15 02:59:37 Removed all existing containers
# >>>   2021/03/15 02:59:37 Check if container train-diabetes-in-custom-environment_1615777097_9dbaf538 already exist exited with 0,
# >>>
# >>>   2021/03/15 02:59:37 Check if container train-diabetes-in-custom-environment_1615777097_9dbaf538 already exist exited with 0,
# >>>
# >>>   2021/03/15 02:59:45 Container ssh is not required for job type.
# >>>   2021/03/15 02:59:45 Starting docker container succeeded.
# >>>   2021/03/15 02:59:45 Starting docker container succeeded.
# >>>   2021/03/15 02:59:45 Disk space after starting docker container: 26251MB
# >>>   2021/03/15 02:59:45 Begin execution of runSpecialJobTask
# >>>   2021/03/15 02:59:45 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs
# >>>   2021/03/15 02:59:45 runSpecialJobTask: Raw cmd for preparation is passed is: python /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538-setup/job_prep.py --snapshots '[{"Id":"81b7ba72-1d1f-4ffb-9652-333fb9b26106","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/15 02:59:45 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs/65_job_prep-tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d.txt
# >>>   2021/03/15 02:59:45 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/azureml_compute_logs/65_job_prep-tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d.txt
# >>>   2021/03/15 02:59:45 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538;python /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538-setup/job_prep.py --snapshots '[{"Id":"81b7ba72-1d1f-4ffb-9652-333fb9b26106","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/15 02:59:45 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/03/15 02:59:45 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 1
# >>>   FilteredData: 0.
# >>>   2021/03/15 02:59:45 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-3a7c9485fd56a88e8bdc4008600df4f1-67857d11c1fe2d9a-01 -t train-diabetes-in-custom-environment_1615777097_9dbaf538 bash -c source /etc/bash.bashrc; PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/4e2b9c2e-c1e4-455e-a4c4-7538f48285dd/job-1/train-diabetes-in-cu_6680ff78-d705-4214-8581-c9a82740ea41/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538;python /mnt/batch/tasks/shared/LS_root/jobs/tbexamaml/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538/mounts/workspaceblobstore/azureml/train-diabetes-in-custom-environment_1615777097_9dbaf538-setup/job_prep.py --snapshots '[{"Id":"81b7ba72-1d1f-4ffb-9652-333fb9b26106","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/15 02:59:51 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:46.104375] Entering job preparation.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:47.385410] Starting job preparation.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:47.385443] Extracting the control code.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:47.402993] fetching and extracting the control code on master node.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:47.403063] Starting extract_project.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:47.403150] Starting to extract zip file.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:47.946723] Finished extracting zip file.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:48.076572] Using urllib.request Python 3.0 or later
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:48.076676] Start fetching snapshots.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:48.076715] Start fetching snapshot.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:48.076731] Retrieving project from snapshot: 81b7ba72-1d1f-4ffb-9652-333fb9b26106
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 605
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.508386] Finished fetching snapshot.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.508421] Finished fetching snapshots.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.508432] Finished extract_project.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.523213] Finished fetching and extracting the control code.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.527377] downloadDataStore - Download from datastores if requested.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.528744] Start run_history_prep.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.580546] Entering context manager injector.
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:50.633857] downloadDataStore completed
# >>>   2021/03/15 02:59:51 runSpecialJobTask: preparation: [2021-03-15T02:59:51.573443] Job preparation is complete.
# >>>   2021/03/15 02:59:51 Execution of runSpecialJobTask completed
# >>>   2021/03/15 02:59:51 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/03/15 02:59:51 Process Exiting with Code:  0
# >>>   2021/03/15 02:59:52 All App Insights Logs was send successfully
# >>>
# 2021-03-15T02:59:52Z 127.0.0.1 slots=4 max-slots=4
# 2021-03-15T02:59:52Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d.txt
# ===============================================================================================================
#
# [2021-03-15T03:00:26.430524] Entering job release
# [2021-03-15T03:00:27.682796] Starting job release
# [2021-03-15T03:00:27.718462] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 777
# [2021-03-15T03:00:27.721348] job release stage : upload_datastore starting...
# [2021-03-15T03:00:27.726036] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-15T03:00:27.742826] job release stage : execute_job_release starting...
# [2021-03-15T03:00:27.747393] job release stage : copy_batchai_cached_logs starting...
# [2021-03-15T03:00:27.747981] job release stage : copy_batchai_cached_logs completed...
# [2021-03-15T03:00:27.752327] Entering context manager injector.
# [2021-03-15T03:00:27.767240] job release stage : upload_datastore completed...
# [2021-03-15T03:00:28.171166] job release stage : execute_job_release completed...
# [2021-03-15T03:00:32.935370] job release stage : send_run_telemetry starting...
# [2021-03-15T03:00:33.110973] get vm size and vm region successfully.
# [2021-03-15T03:00:33.125029] get compute meta data successfully.
# [2021-03-15T03:00:35.455101] post artifact meta request successfully.
# [2021-03-15T03:00:35.492159] upload compute record artifact successfully.
# [2021-03-15T03:00:38.762316] job release stage : send_run_telemetry completed...
# [2021-03-15T03:00:38.762753] Job release is complete
#
# Execution Summary
# =================
# RunId: train-diabetes-in-custom-environment_1615777097_9dbaf538
# Web View: https://ml.azure.com/experiments/train-diabetes-in-custom-environment/runs/train-diabetes-in-custom-environment_1615777097_9dbaf538?wsid=/subscriptions/7ee5c9fb-ba32-4243-af24-bda7af98f453/resourcegroups/tbexamaml/workspaces/tbexamaml
#
# Regularization Rate 0.01
# Accuracy 0.774
# AUC 0.8484437036668493
#
#
# azureml-logs/55_azureml-execution-tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d.txt
# azureml-logs/65_job_prep-tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d.txt
# azureml-logs/70_driver_log.txt
# azureml-logs/75_job_post-tvmps_826b8cb4838b93ade22dabb217dc64247e8c4ad564a550fdf2498431fa1b4b55_d.txt
# azureml-logs/process_info.json
# azureml-logs/process_status.json
# logs/azureml/650_azureml.log
# logs/azureml/job_prep_azureml.log
# logs/azureml/job_release_azureml.log
# outputs/diabetes_model.pkl
